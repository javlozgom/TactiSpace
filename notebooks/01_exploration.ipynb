# %% [markdown]
# # 01 - Exploracion inicial
#
# Este notebook sirve como fase de exploracion previa a mover la logica reutilizable al paquete `src/`.

# %%
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt

from src.visualizations import plot_events_on_pitch

# %%
data_path = Path('data/processed/events.parquet')
df = pd.read_parquet(data_path)
df.head()

# %%
df.info()

# %%
df['event_type'].value_counts()

# %%
df['player'].value_counts()

# %%
fig = plot_events_on_pitch(df, title='Visualizacion exploratoria de eventos')
plt.show()

# %% [markdown]
# La idea es usar este notebook para validar datos y patrones rapidamente, y despues consolidar la logica estable en modulos reutilizables dentro de `src/`.
